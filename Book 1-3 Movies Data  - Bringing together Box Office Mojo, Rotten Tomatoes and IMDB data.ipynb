# %%
import pandas as pd

# %%
from os import listdir

# get list of all files in the scripts directory
files = [f for f in listdir('\\scripts\\')]

# %%
len(files)
# Out:
# 2572

# %%
# create a dictionary with key as filename and script as value
scripts_dict = {}
for fl in files:
    file_path = 'scripts\\' + fl
    with open(file_path) as f:
        txt = f.read()
        scripts_dict[fl] = txt

# %%
# convert the dictionary to a pandas dataframe
scripts_df = pd.DataFrame(scripts_dict.items(), columns=['genre_movie_name', 'script'])

# %%
scripts_df.head()
# Out:
#                  genre_movie_name  \
# 0    action_collateral-damage.txt
# 1      comedy_very-bad-things.txt
# 2  comedy_lost-in-translation.txt
# 3        mystery_citizen-kane.txt
# 4          drama_pearl-harbor.txt
#
#                                               script
# 0      COLLATERAL DAMAGE\n                       ...
# 1                                      "VERY BAD ...
# 2  \n\n\n\n\n\n\n                                ...
# 3  \n\n                                  Citizen ...
# 4  \n\n\n\n                              by\n\n  ...

# %%
# remove .txt suffix from movie_name column
scripts_df['movie_name'] = scripts_df['genre_movie_name'].apply(lambda x: x.replace('.txt', '').split('_')[1])
scripts_df['genre'] = scripts_df['genre_movie_name'].apply(lambda x: x.replace('.txt', '').split('_')[0])

# %%
scripts_df = scripts_df.drop('genre_movie_name', axis=1)

# %%
genre_combined = pd.DataFrame(scripts_df[['movie_name', 'genre']].groupby(['movie_name']).agg(list)).reset_index()
scripts_df = scripts_df.drop('genre', axis=1)

scripts_df = scripts_df.sort_values(by=['movie_name'])
scripts_df = scripts_df.drop_duplicates(subset=['movie_name'], keep='last')
scripts_df.shape
# Out:
# (957, 2)

# %%
scripts_df = pd.merge(scripts_df, genre_combined, on='movie_name', how='left')

# %%
scripts_df.head()
# Out:
#                                               script  \
# 0                  written by Karen McCullah Lutz...
# 1  \n\nFin of red 1957 Chevy Impala convertible d...
# 2             \n\n                               ...
# 3  \n\n\t\t          An original screenplay by\n\...
# 4  \n \n\n\n\n\n                                 ...
#
#                    movie_name                               genre
# 0  10-things-i-hate-about-you                   [comedy, romance]
# 1                          12                            [comedy]
# 2              12-and-holding                             [drama]
# 3                  12-monkeys  [drama, thriller, science-fiction]
# 4                   127-hours        [drama, adventure, thriller]

# %%
scripts_df.shape
# Out:
# (957, 3)

# %%
names_df = pd.DataFrame(scripts_df.copy()['movie_name'])

# %%
names_df
# Out:
#                   movie_name
# 0          collateral-damage
# 1            very-bad-things
# 2        lost-in-translation
# 3               citizen-kane
# 4               pearl-harbor
# ...                      ...
# 2567               anastasia
# 2568         the-ladykillers
# 2569  the-talented-mr-ripley
# 2570                watchmen
# 2571               king-kong
#
# [2572 rows x 1 columns]

# %%
box_df = pd.read_csv('boxoffice_data_clean.csv')

# %%
import re
def preprocess_title(x):
    if isinstance(x, str):
        x = x.lower()
        x = x.replace("'", '')
        x = re.sub('\W+\s*', ' ', x)
        x = x.replace(' ', '-')
        return x
    else:
        return ''

# %%
box_df['movie_name'] = box_df['title'].apply(preprocess_title)

# %%
box_df
# Out:
#        Unnamed: 0                                 title  lifetime_gross  year  \
# 0               0          Star Wars: The Force Awakens       936662225  2015
# 1               1                                Avatar       760507625  2009
# 2               2                         Black Panther       700059566  2018
# 3               3                Avengers: Infinity War       678681680  2018
# 4               4                               Titanic       659363944  1997
# ...           ...                                   ...             ...   ...
# 15738       15738                           Dog Eat Dog              80  2009
# 15739       15739                        Paranoid Girls              78  2015
# 15740       15740  Confession of a Child of the Century              74  2015
# 15741       15741                            Storage 24              72  2013
# 15742       15742                           Zyzzyx Road              30  2006
#
#                                  movie_name
# 0               star-wars-the-force-awakens
# 1                                    avatar
# 2                             black-panther
# 3                     avengers-infinity-war
# 4                                   titanic
# ...                                     ...
# 15738                           dog-eat-dog
# 15739                        paranoid-girls
# 15740  confession-of-a-child-of-the-century
# 15741                            storage-24
# 15742                           zyzzyx-road
#
# [15743 rows x 5 columns]

# %%
partial_box = pd.read_csv('matched_titles - box.csv')
partial_box
# Out:
#                                            movie_title  \
# 0                            evil-dead-ii-dead-by-dawn
# 1      friday-the-13th-part-viii-jason-takes-manhattan
# 2                     rambo-first-blood-ii-the-mission
# 3    the-adventures-of-buckaroo-banzai-across-the-e...
# 4                                             scarface
# ..                                                 ...
# 109                                            alien-3
# 110                                   kate-and-leopold
# 111                                                187
# 112                                             simone
# 113                                    the-surfer-king
#
#                             movie_name  match_score
# 0                          evil-dead-2           56
# 1            friday-the-13th-part-viii           69
# 2            rambo-first-blood-part-ii           70
# 3    the-adventures-of-buckaroo-banzai           70
# 4                       scarface-1983-           73
# ..                                 ...          ...
# 109                            alien-3          100
# 110                   kate-and-leopold          100
# 111                                187          100
# 112                             simone          100
# 113                    the-surfer-king          100
#
# [114 rows x 3 columns]

# %%
names_df = names_df.drop_duplicates()

# %%
names_df
# Out:
#                movie_name
# 0       collateral-damage
# 1         very-bad-things
# 2     lost-in-translation
# 3            citizen-kane
# 4            pearl-harbor
# ...                   ...
# 2478     the-elephant-man
# 2488            frequency
# 2513              amadeus
# 2535        thirteen-days
# 2542    the-hebrew-hammer
#
# [957 rows x 1 columns]

# %%
tmp_df = pd.merge(box_df, partial_box, on='movie_name', how='left')
tmp_df['movie_title'].fillna('0', inplace=True)
tmp_df['movie_name_new'] = tmp_df.apply(lambda x: x['movie_name'] if x['movie_title']=='0' else x['movie_title'], axis=1)
tmp_df['movie_name'] = tmp_df['movie_name_new']

joint = pd.merge(names_df, tmp_df, on='movie_name', how='left')
joint[~joint['title'].isnull()]['movie_name'].nunique()
joint = joint.drop_duplicates()

# %%
print(joint.shape)
# Out:
# (961, 8)

# %%
joint1 = pd.merge(names_df, box_df, on='movie_name', how='left')

# %%
joint1
# Out:
#                   movie_name  Unnamed: 0                    title  \
# 0          collateral-damage      2052.0        Collateral Damage
# 1            very-bad-things      4669.0          Very Bad Things
# 2        lost-in-translation      1850.0      Lost in Translation
# 3               citizen-kane      7055.0             Citizen Kane
# 4               pearl-harbor       198.0             Pearl Harbor
# ...                      ...         ...                      ...
# 2579               anastasia      1383.0                Anastasia
# 2580         the-ladykillers      2061.0          The Ladykillers
# 2581  the-talented-mr-ripley       912.0  The Talented Mr. Ripley
# 2582                watchmen       615.0                 Watchmen
# 2583               king-kong       159.0                King Kong
#
#       lifetime_gross    year
# 0         40077257.0  2002.0
# 1          9898412.0  1998.0
# 2         44585453.0  2003.0
# 3          1585634.0  1941.0
# 4        198542554.0  2001.0
# ...              ...     ...
# 2579      58406347.0  1997.0
# 2580      39799191.0  2004.0
# 2581      81298265.0  1999.0
# 2582     107509799.0  2009.0
# 2583     218080025.0  2005.0
#
# [2584 rows x 5 columns]

# %%
unmatched = joint1[joint1['title'].isnull()]['movie_name']

# %%
unmatched
# Out:
# 6                              john-q
# 7                    perfect-creature
# 9                           evil-dead
# 22                 cowboys-and-aliens
# 35                love-and-basketball
#                     ...
# 2560                 orgy-of-the-dead
# 2569                      heavy-metal
# 2572    star-wars-revenge-of-the-sith
# 2576               grosse-point-blank
# 2577           the-planet-of-the-apes
# Name: movie_name, Length: 494, dtype: object

# %%
mv_df = pd.read_csv('movies_metadata_clean.csv')
mv_df['title'].fillna('')
mv_df['movie_name'] = mv_df['title'].apply(preprocess_title)

# %%
mv_df
# Out:
#        Unnamed: 0  belongs_to_collection                              genres  \
# 0               0                      1   ['Comedy', 'Family', 'Animation']
# 1               1                      0  ['Fantasy', 'Family', 'Adventure']
# 2               2                      1               ['Comedy', 'Romance']
# 3               3                      0      ['Drama', 'Comedy', 'Romance']
# 4               4                      1                          ['Comedy']
# ...           ...                    ...                                 ...
# 45461       45461                      0                 ['Drama', 'Family']
# 45462       45462                      0                           ['Drama']
# 45463       45463                      0     ['Drama', 'Action', 'Thriller']
# 45464       45464                      0                                  []
# 45465       45465                      0                                  []
#
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                      رگ خواب
# 45462          Siglo ng Pagluluwal
# 45463                     Betrayal
# 45464          Satana likuyushchiy
# 45465                     Queerama
#
#                                     production_companies release_date  \
# 0                            ['Pixar Animation Studios']   1995-10-30
# 1      ['Interscope Communications', 'TriStar Picture...   1995-12-15
# 2                     ['Lancaster Gate', 'Warner Bros.']   1995-12-22
# 3             ['Twentieth Century Fox Film Corporation']   1995-12-22
# 4       ['Touchstone Pictures', 'Sandollar Productions']   1995-02-10
# ...                                                  ...          ...
# 45461                                                 []          NaN
# 45462                                    ['Sine Olivia']   2011-11-17
# 45463                        ['American World Pictures']   2003-08-01
# 45464                                      ['Yermoliev']   1917-10-21
# 45465                                                 []   2017-06-09
#
#            revenue  runtime         spoken_languages  \
# 0      373554033.0     81.0              ['English']
# 1      262797249.0    104.0  ['Français', 'English']
# 2              0.0    101.0              ['English']
# 3       81452156.0    127.0              ['English']
# 4       76578911.0    106.0              ['English']
# ...            ...      ...                      ...
# 45461          0.0     90.0                ['فارسی']
# 45462          0.0    360.0                     ['']
# 45463          0.0     90.0              ['English']
# 45464          0.0     87.0                       []
# 45465          0.0     75.0              ['English']
#
#                              title  vote_average  vote_count  \
# 0                        Toy Story           7.7      5415.0
# 1                          Jumanji           6.9      2413.0
# 2                 Grumpier Old Men           6.5        92.0
# 3                Waiting to Exhale           6.1        34.0
# 4      Father of the Bride Part II           5.7       173.0
# ...                            ...           ...         ...
# 45461                       Subdue           4.0         1.0
# 45462          Century of Birthing           9.0         3.0
# 45463                     Betrayal           3.8         6.0
# 45464             Satan Triumphant           0.0         0.0
# 45465                     Queerama           0.0         0.0
#
#                         movie_name
# 0                        toy-story
# 1                          jumanji
# 2                 grumpier-old-men
# 3                waiting-to-exhale
# 4      father-of-the-bride-part-ii
# ...                            ...
# 45461                       subdue
# 45462          century-of-birthing
# 45463                     betrayal
# 45464             satan-triumphant
# 45465                     queerama
#
# [45466 rows x 13 columns]

# %%
partial_mv = pd.read_csv('matched_titles - mv.csv')
partial_mv
tmp_df = pd.merge(mv_df, partial_mv, on='movie_name', how='left')
tmp_df['movie_title'].fillna('0', inplace=True)
tmp_df['movie_name_new'] = tmp_df.apply(lambda x: x['movie_name'] if x['movie_title']=='0' else x['movie_title'], axis=1)
tmp_df['movie_name'] = tmp_df['movie_name_new']

joint_ = pd.merge(joint, tmp_df, on='movie_name', how='left')
joint_
joint_[~joint_['vote_average'].isnull()]['movie_name'].nunique()
# Out:
# 925

# %%
joint_.drop_duplicates().shape
# Out:
# (1170, 23)

# %%
joint2 = pd.merge(names_df, mv_df, on='movie_name', how='left')

# %%
unmatched2 = joint2[joint2['title'].isnull()]['movie_name']

# %%
unmatched2
# Out:
# 7                        perfect-creature
# 23                     cowboys-and-aliens
# 39                    love-and-basketball
# 48                      godfather-part-ii
# 57               pirates-of-the-caribbean
#                       ...
# 3110                    twilight-new-moon
# 3115    star-wars-the-empire-strikes-back
# 3141        star-wars-revenge-of-the-sith
# 3145                   grosse-point-blank
# 3146               the-planet-of-the-apes
# Name: movie_name, Length: 308, dtype: object

# %%
unmatched_all = list(set(list(unmatched) + list(unmatched2)))

# %%
len(unmatched_all)
# Out:
# 199

# %%
unmatched_df = pd.DataFrame(unmatched_all)

# %%
unmatched_df.columns = ['movie_title']

# %%
! pip install fuzzywuzzy

# %%
from fuzzywuzzy import fuzz

def fuzzy_match(str1, str2):
    return fuzz.ratio(str1, str2)

# %%
unmatched_df['tmp'] = 1
box_df['tmp'] = 1
mv_df['tmp'] = 1

# %%
unmatched_box = pd.merge(unmatched_df, box_df, how='outer', on='tmp')

# %%
unmatched_box.shape

# %%
unmatched_box

# %%
unmatched_box['match_score'] = unmatched_box.apply(lambda x: fuzzy_match(x['movie_title'], x['movie_name']), axis=1)

# %%
unmatched_box[unmatched_box['match_score'] >= 70]

# %%
unmatched_mv = pd.merge(unmatched_df, mv_df, how='outer', on='tmp')

# %%
unmatched_mv.shape

# %%
unmatched_mv['match_score'] = unmatched_mv.apply(lambda x: fuzzy_match(x['movie_title'], x['movie_name']), axis=1)

# %%
unmatched_mv[unmatched_mv['match_score'] >= 60]

# %%
# unmatched_mv.to_csv('unmatched_mv.csv')

# %%
# unmatched_box.to_csv('unmatched_box.csv')

# %%
joint_.columns
# Out:
# Index(['movie_name', 'Unnamed: 0_x', 'title_x', 'lifetime_gross', 'year',
#        'movie_title_x', 'match_score_x', 'movie_name_new_x', 'Unnamed: 0_y',
#        'belongs_to_collection', 'genres', 'original_title',
#        'production_companies', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'title_y', 'vote_average', 'vote_count',
#        'movie_title_y', 'match_score_y', 'movie_name_new_y'],
#       dtype='object')

# %%
joint_ = joint_.drop(['Unnamed: 0_x', 'title_x',
                      'movie_title_x', 'match_score_x', 
                      'movie_name_new_x', 'Unnamed: 0_y', 
                      'title_y', 'movie_title_y', 
                      'match_score_y', 'movie_name_new_y'], 
                     axis=1)

# %%
joint_.head()
# Out:
#             movie_name  lifetime_gross    year  belongs_to_collection  \
# 0    collateral-damage      40077257.0  2002.0                    0.0
# 1      very-bad-things       9898412.0  1998.0                    0.0
# 2  lost-in-translation      44585453.0  2003.0                    0.0
# 3         citizen-kane       1585634.0  1941.0                    0.0
# 4         pearl-harbor     198542554.0  2001.0                    0.0
#
#                             genres       original_title  \
# 0  ['Drama', 'Action', 'Thriller']    Collateral Damage
# 1  ['Comedy', 'Crime', 'Thriller']      Very Bad Things
# 2                        ['Drama']  Lost in Translation
# 3             ['Mystery', 'Drama']         Citizen Kane
# 4    ['War', 'Romance', 'History']         Pearl Harbor
#
#                                 production_companies release_date  \
# 0  ['David Foster Productions', 'Hacienda Product...   2002-02-06
# 1  ['Ballpark Productions Partnership', 'Intersco...   1998-09-11
# 2                              ['American Zoetrope']   2003-08-31
# 3      ['Mercury Productions', 'RKO Radio Pictures']   1941-04-30
# 4  ['Touchstone Pictures', 'Jerry Bruckheimer Fil...   2001-05-21
#
#        revenue  runtime                spoken_languages  vote_average  \
# 0   78382433.0    108.0          ['Español', 'English']           5.5
# 1    9898412.0    100.0                     ['English']           6.2
# 2  119723856.0    102.0              ['日本語', 'English']           7.3
# 3   23217674.0    119.0                     ['English']           8.0
# 4  449220945.0    183.0  ['Français', '日本語', 'English']           6.6
#
#    vote_count
# 0       431.0
# 1       182.0
# 2      1943.0
# 3      1244.0
# 4      1833.0

# %%
joint_ = joint_.drop_duplicates()
joint_.shape
# Out:
# (1169, 13)

# %%
joint_ = joint_.sort_values(by=['movie_name','year'])
joint_ = joint_.drop_duplicates(subset=['movie_name'], keep='last')

# %%
joint_.shape
# Out:
# (957, 13)

# %%
merged_df = pd.merge(scripts_df, joint_, on='movie_name', how='left')

# %%
merged_df.head()
# Out:
#                                               script  \
# 0                  written by Karen McCullah Lutz...
# 1  \n\nFin of red 1957 Chevy Impala convertible d...
# 2             \n\n                               ...
# 3  \n\n\t\t          An original screenplay by\n\...
# 4  \n \n\n\n\n\n                                 ...
#
#                    movie_name                               genre  \
# 0  10-things-i-hate-about-you                   [comedy, romance]
# 1                          12                            [comedy]
# 2              12-and-holding                             [drama]
# 3                  12-monkeys  [drama, thriller, science-fiction]
# 4                   127-hours        [drama, adventure, thriller]
#
#    lifetime_gross    year  belongs_to_collection  \
# 0      38178166.0  1999.0                    0.0
# 1        125120.0  2009.0                    0.0
# 2         96464.0  2006.0                    0.0
# 3      57141459.0  1995.0                    NaN
# 4      18335230.0  2010.0                    0.0
#
#                                genres              original_title  \
# 0      ['Drama', 'Comedy', 'Romance']  10 Things I Hate About You
# 1                  ['Drama', 'Crime']                          12
# 2                           ['Drama']          Twelve and Holding
# 3                                 NaN                         NaN
# 4  ['Drama', 'Adventure', 'Thriller']                   127 Hours
#
#                                 production_companies release_date     revenue  \
# 0  ['Jaret Entertainment', 'Mad Chance', 'Touchst...   1999-03-30  53478166.0
# 1                          ['venezia 64', 'Mosfilm']   2007-06-06   7537453.0
# 2                                 ['Serenade Films']   2005-09-11     95687.0
# 3                                                NaN          NaN         NaN
# 4  ['Fox Searchlight Pictures', 'Cloud Eight Film...   2010-11-05  35692920.0
#
#    runtime          spoken_languages  vote_average  vote_count
# 0     97.0   ['Français', 'English']           7.3      1768.0
# 1    159.0  ['', 'Pусский', 'Český']           6.6        54.0
# 2     90.0               ['English']           7.0        20.0
# 3      NaN                       NaN           NaN         NaN
# 4     94.0               ['English']           7.0      2668.0

# %%
merged_df.shape
# Out:
# (957, 15)

# %%
merged_df.to_csv('merged_box_mv_script.csv')

# %%
rt_df = pd.read_csv('rotten_tomatoes - Sheet2 (1).csv')
rt_df['movie_name'] = rt_df['movie_name'].apply(lambda x: x.replace('_', '-'))

# %%
rt_df
# Out:
#                      movie_name  rt_critic_score  rt_audience_score
# 0                    the-losers             48.0               54.0
# 1       the-blast-from-the-past             58.0               56.0
# 2       x-men-origins-wolverine             38.0               58.0
# 3    hellraiser-3-hell-on-earth             42.0               35.0
# 4              mulholland-drive             84.0               87.0
# ..                          ...              ...                ...
# 948                     warrior             84.0               92.0
# 949                   the-siege             44.0               53.0
# 950                     soldier             13.0               44.0
# 951                out-of-sight             94.0               74.0
# 952                    insomnia             92.0               77.0
#
# [953 rows x 3 columns]

# %%
merged_df = pd.merge(merged_df, rt_df, on='movie_name', how='left')

# %%
merged_df[~merged_df['rt_critic_score'].isnull()]
# Out:
#                                                 script  \
# 0                    written by Karen McCullah Lutz...
# 1    \n\nFin of red 1957 Chevy Impala convertible d...
# 2               \n\n                               ...
# 3    \n\n\t\t          An original screenplay by\n\...
# 4    \n \n\n\n\n\n                                 ...
# ..                                                 ...
# 952             \n\n                             Wr...
# 953                                    "YOU CAN COU...
# 954   \n\n\n\n\n\n                                 ...
# 955  \t\t\tYou've Got Mail\n\n\t\t\tby Nora Ephron ...
# 956  \n\n\n\n\n\n                                  ...
#
#                      movie_name                               genre  \
# 0    10-things-i-hate-about-you                   [comedy, romance]
# 1                            12                            [comedy]
# 2                12-and-holding                             [drama]
# 3                    12-monkeys  [drama, thriller, science-fiction]
# 4                     127-hours        [drama, adventure, thriller]
# ..                          ...                                 ...
# 952                     yes-man                   [comedy, romance]
# 953         you-can-count-on-me                             [drama]
# 954             youth-in-revolt            [romance, drama, comedy]
# 955              youve-got-mail                   [romance, comedy]
# 956                  zerophilia                   [romance, comedy]
#
#      lifetime_gross    year  belongs_to_collection  \
# 0        38178166.0  1999.0                    0.0
# 1          125120.0  2009.0                    0.0
# 2           96464.0  2006.0                    0.0
# 3        57141459.0  1995.0                    NaN
# 4        18335230.0  2010.0                    0.0
# ..              ...     ...                    ...
# 952      97690976.0  2008.0                    0.0
# 953       9183362.0  2000.0                    0.0
# 954      15281286.0  2010.0                    0.0
# 955     115821495.0  1998.0                    0.0
# 956          7763.0  2006.0                    0.0
#
#                                  genres              original_title  \
# 0        ['Drama', 'Comedy', 'Romance']  10 Things I Hate About You
# 1                    ['Drama', 'Crime']                          12
# 2                             ['Drama']          Twelve and Holding
# 3                                   NaN                         NaN
# 4    ['Drama', 'Adventure', 'Thriller']                   127 Hours
# ..                                  ...                         ...
# 952                          ['Comedy']                     Yes Man
# 953                ['Drama', 'Romance']         You Can Count on Me
# 954      ['Drama', 'Comedy', 'Romance']             Youth in Revolt
# 955               ['Comedy', 'Romance']             You've Got Mail
# 956               ['Comedy', 'Romance']                 Zerophillia
#
#                                   production_companies release_date  \
# 0    ['Jaret Entertainment', 'Mad Chance', 'Touchst...   1999-03-30
# 1                            ['venezia 64', 'Mosfilm']   2007-06-06
# 2                                   ['Serenade Films']   2005-09-11
# 3                                                  NaN          NaN
# 4    ['Fox Searchlight Pictures', 'Cloud Eight Film...   2010-11-05
# ..                                                 ...          ...
# 952  ['Village Roadshow Pictures', 'The Zanuck Comp...   2008-12-09
# 953  ['Cappa Productions', 'Hart-Sharp Entertainmen...   2000-11-17
# 954                                ['Dimension Films']   2009-09-11
# 955                                   ['Warner Bros.']   1998-12-17
# 956     ['Microangelo Entertainment', 'TLA Releasing']   2005-10-13
#
#          revenue  runtime                 spoken_languages  vote_average  \
# 0     53478166.0     97.0          ['Français', 'English']           7.3
# 1      7537453.0    159.0         ['', 'Pусский', 'Český']           6.6
# 2        95687.0     90.0                      ['English']           7.0
# 3            NaN      NaN                              NaN           NaN
# 4     35692920.0     94.0                      ['English']           7.0
# ..           ...      ...                              ...           ...
# 952  225990978.0    104.0  ['한국어/조선말', 'English', 'Eesti']           6.4
# 953          0.0    111.0                      ['English']           6.8
# 954          0.0     87.0          ['Français', 'English']           5.9
# 955  250821495.0    119.0                      ['English']           6.3
# 956          0.0     90.0                      ['English']           5.1
#
#      vote_count  rt_critic_score  rt_audience_score
# 0        1768.0             70.0               69.0
# 1          54.0              0.0                0.0
# 2          20.0             74.0               80.0
# 3           NaN             88.0               88.0
# 4        2668.0             93.0               85.0
# ..          ...              ...                ...
# 952      1869.0             46.0               66.0
# 953        89.0             95.0               88.0
# 954       323.0             66.0               52.0
# 955       859.0             69.0               73.0
# 956        15.0             25.0               61.0
#
# [933 rows x 17 columns]

# %%
merged_df.to_csv('merged_box_mv_rt_scripts.csv')
