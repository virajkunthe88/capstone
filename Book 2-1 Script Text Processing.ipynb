# %%
import string
import pandas as pd
from os import listdir

# get list of all files in the scripts directory
files = [f for f in listdir("scripts\\")]

# %%
! pip install nltk

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
# create a dictionary with key as filename and script as value
scripts_dict = {}
for fl in files:
    file_path = 'scripts\\' + fl
#     print(file_path)
    with open(file_path, encoding="utf8") as f:
        txt = f.read()
        scripts_dict[fl] = txt

# %%
# convert the dictionary to a pandas dataframe

scripts_df = pd.DataFrame(scripts_dict.items(), columns=['genre_movie_name', 'script'])

# %%
# remove .txt suffix from movie_name column

scripts_df['movie_name'] = scripts_df['genre_movie_name'].apply(lambda x: x.replace('.txt', '').split('_')[1])
scripts_df['genre'] = scripts_df['genre_movie_name'].apply(lambda x: x.replace('.txt', '').split('_')[0])

# %%
# grouping the genres into a list of genres

genre_df = scripts_df[['movie_name', 'genre']]

genre_df = pd.DataFrame(genre_df.groupby('movie_name').agg(list)).reset_index()
genre_df
# Out:
#                      movie_name                               genre
# 0    10-things-i-hate-about-you                   [comedy, romance]
# 1                            12                            [comedy]
# 2                12-and-holding                             [drama]
# 3                    12-monkeys  [drama, science-fiction, thriller]
# 4                     127-hours        [adventure, drama, thriller]
# ..                          ...                                 ...
# 949                     yes-man                   [comedy, romance]
# 950         you-can-count-on-me                             [drama]
# 951             youth-in-revolt            [comedy, drama, romance]
# 952              youve-got-mail                   [comedy, romance]
# 953                  zerophilia                   [comedy, romance]
#
# [954 rows x 2 columns]

# %%
# drop duplicates in scripts and movie_name columns

scripts_df = scripts_df[['script', 'movie_name']].drop_duplicates()

# %%
scripts_df = pd.merge(scripts_df, genre_df, how='left', on='movie_name')

# %%
scripts_df.shape
# Out:
# (954, 3)

# %%
scripts_df
# Out:
#                                                 script          movie_name  \
# 0    \n\n\n\ton the words CZECH AIRLINE.  We are pa...          15-minutes
# 1               \n\n                               ...                2012
# 2    \n\n\n\n\n\n\n                                ...  30-minutes-or-less
# 3    \n\n\n\n\n\n              Endless green hills ...              48-hrs
# 4    A PERFECT WORLD\n\n       Written by\n\n\n\n\n...     a-perfect-world
# ..                                                 ...                 ...
# 949  \n\n\n\n                              Written ...              shifty
# 950  \n\n\n\n\n\n\nThe screen is black. Thunder rum...            spare-me
# 951  \n\n\n\n\n\n\n                                ...      the-assignment
# 952  \n\n\n\n\n\n\n                                ...           roughshod
# 953  \n\n\n\n\n                                    ...        station-west
#
#                                                  genre
# 0                            [action, crime, thriller]
# 1    [action, adventure, drama, science-fiction, th...
# 2                          [action, adventure, comedy]
# 3                           [action, comedy, thriller]
# 4                               [action, crime, drama]
# ..                                                 ...
# 949                                         [thriller]
# 950                                         [thriller]
# 951                                         [thriller]
# 952                                          [western]
# 953                                          [western]
#
# [954 rows x 3 columns]

# %%
def get_tagged_sentences(txt):
    sentence = nltk.sent_tokenize(txt)
    tagged_sentences = []
    for sent in sentence:
        tagged_sentences.append(nltk.pos_tag(nltk.word_tokenize(sent)))
    return tagged_sentences

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.corpus import stopwords 

def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return ''

def get_lemmatized_words(tagged_sentences):
    lemmatizer = WordNetLemmatizer()
    ENGLISH_STOP_WORDS = stopwords.words('english')
    all_words = []
    for sent in tagged_sentences:
        for (word, pos) in sent:
            if word not in string.punctuation and word not in ENGLISH_STOP_WORDS:
                wnet_pos = get_wordnet_pos(pos)
                if wnet_pos != '':
                    all_words.append(lemmatizer.lemmatize(word, wnet_pos))
                else:
                    all_words.append(lemmatizer.lemmatize(word))
    return all_words

# %%
def get_pos_simple(treebank_tag):

    if treebank_tag.startswith('J'):
        return 'adj'
    elif treebank_tag.startswith('V'):
        return 'verb'
    elif treebank_tag.startswith('N'):
        if treebank_tag.startswith('NNP'):
            return 'proper_noun'
        return 'noun'
    elif treebank_tag.startswith('R'):
        return 'adv'
    else:
        return ''

def get_pos_counts(tagged_sentences):
    pos_dict = {}
    proper_nouns = []
    for sent in tagged_sentences:
        for (wrd,pos) in sent:
            pos = get_pos_simple(pos)
            if pos == 'proper_noun':
                proper_nouns.append(wrd)
                pos = 'noun'
            if pos in pos_dict:
                pos_dict[pos] += [wrd]
            else:
                pos_dict[pos] = [wrd]
    pos_count_dict = {}
    pos_unique_count_dict = {}
    for item in pos_dict:
        pos_count_dict[item] = len(pos_dict[item])
        pos_unique_count_dict[item] = len(set(pos_dict[item])) # converting to unique words only
    return len(list(set(proper_nouns))), len(proper_nouns), pos_count_dict, pos_unique_count_dict

# %%
def extract_text_features(row):
    txt = row['script']
    txt = txt.replace('\n',' ').replace('\t', ' ').replace('\r', ' ')
    sent = get_tagged_sentences(txt)
    sentence_count = len(sent)
    words = get_lemmatized_words(sent)
    word_count = len(words)
    words_nunique = len(set(words))
    (prop_nunique, prop_count, pos_counts_dict, pos_nunique_dict) = get_pos_counts(sent)
    verb_percent = pos_counts_dict['verb']*100.0/word_count
    noun_percent = pos_counts_dict['noun']*100.0/word_count
    adj_percent = pos_counts_dict['adj']*100.0/word_count
    adv_percent = pos_counts_dict['adv']*100.0/word_count

    verb_unique_percent = pos_nunique_dict['verb']*100.0/words_nunique
    noun_unique_percent = pos_nunique_dict['noun']*100.0/words_nunique
    adj_unique_percent = pos_nunique_dict['adj']*100.0/words_nunique
    adv_unique_percent = pos_nunique_dict['adv']*100.0/words_nunique

    return [prop_count, verb_percent, noun_percent, adj_percent, adv_percent,
            prop_nunique, verb_unique_percent, noun_unique_percent, 
            adj_unique_percent, adv_unique_percent]
#     except:
#         print(row['movie_name'])

# %%
scripts_df
# Out:
#                                                 script          movie_name  \
# 0    \n\n\n\ton the words CZECH AIRLINE.  We are pa...          15-minutes
# 1               \n\n                               ...                2012
# 2    \n\n\n\n\n\n\n                                ...  30-minutes-or-less
# 3    \n\n\n\n\n\n              Endless green hills ...              48-hrs
# 4    A PERFECT WORLD\n\n       Written by\n\n\n\n\n...     a-perfect-world
# ..                                                 ...                 ...
# 949  \n\n\n\n                              Written ...              shifty
# 950  \n\n\n\n\n\n\nThe screen is black. Thunder rum...            spare-me
# 951  \n\n\n\n\n\n\n                                ...      the-assignment
# 952  \n\n\n\n\n\n\n                                ...           roughshod
# 953  \n\n\n\n\n                                    ...        station-west
#
#                                                  genre
# 0                            [action, crime, thriller]
# 1    [action, adventure, drama, science-fiction, th...
# 2                          [action, adventure, comedy]
# 3                           [action, comedy, thriller]
# 4                               [action, crime, drama]
# ..                                                 ...
# 949                                         [thriller]
# 950                                         [thriller]
# 951                                         [thriller]
# 952                                          [western]
# 953                                          [western]
#
# [954 rows x 3 columns]

# %%
scripts_df['features'] = scripts_df.apply(lambda x: extract_text_features(x), axis=1)

# %%
scripts_df

# %%
scripts_df.to_csv('script_text_features.csv')

# %% [markdown]
# ## ================================================

# %%
with open('scripts\\action_15-minutes.txt', encoding="utf=8") as f:
    txt = f.read()

# %%
txt = txt.replace('\n',' ').replace('\t', ' ').replace('\r', ' ')
sent = get_tagged_sentences(txt)
print(sent)
# Out:
# [[('on', 'IN'), ('the', 'DT'), ('words', 'NNS'), ('CZECH', 'NNP'), ('AIRLINE', 'NNP'), ('.', '.')], [('We', 'PRP'), ('are', 'VBP'), ('panning', 'VBG'), ('across', 'IN'), ('the', 'DT'), ('words', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('side', 'NN'), ('of', 'IN'), ('the', 'DT'), ('plane', 'NN'), ('.', '.')], [('on', 'IN'), ('a', 'DT'), ('tray', 'NN'), ('table', 'NN'), ('.', '.')], [('Crumpled', 'VBN'), ('Czech', 'NNP'), ('bills', 'NNS'), ('and', 'CC'), ('coins', 'NNS'), ('are', 'VBP'), ('on', 'IN'), ('it', 'PRP'), ('.', '.')], [('Hands', 'NNS'), ('are', 'VBP'), ('counting', 'VBG'), ('the', 'DT'), ('money', 'NN'), ('.', '.')], [('The', 'DT'), ('airline', 'NN'), ('hostess', 'NN'), ('announces', 'VBZ'), ('the', 'DT'), ('arrival', 'NN'), ('at', 'IN'), ('JFK', 'NNP'), ('-', ':'), ('in', 'IN'), ('CZECH', 'NNP'), ('.', '.')], [('A', 'DT'), ('hand', 'NN'), ('reaches', 'VBZ'), ('into', 'IN'), ('a', 'DT'), ('breast', 'NN'), ('pocket', 'NN'), ('-', ':'), ('pulling', 'VBG'), ('out', 'RP'), ('two', 'CD'), ('passports', 'NNS'), ('.', '.')], [('One', 'CD'), ('is', 'VBZ'), ('opened', 'VBN'), ('.', '.')], [('Belongs', 'NNS'), ('to', 'TO'), ('EMIL', 'NNP'), ('SLOVAK', 'NNP'), ('.', '.')], [('The', 'DT'), ('next', 'JJ'), ('passport', 'NN'), ('belongs', 'NNS'), ('to', 'TO'), ('OLEG', 'NNP'), ('RAZGUL', 'NNP'), ('.', '.')], [('The', 'DT'), ('hand', 'NN'), ('passes', 'VBZ'), ('the', 'DT'), ('Oleg', 'NNP'), ('Razgul', 'NNP'), ('passport', 'NN'), ('to', 'TO'), ('the', 'DT'), ('man', 'NN'), ('next', 'IN'), ('to', 'TO'), ('him', 'PRP'), ('.', '.')], [('We', 'PRP'), ('notice', 'VBP'), ('several', 'JJ'), ('empty', 'JJ'), ('airline', 'NN'), ('bottles', 'NNS'), ('of', 'IN'), ('vodka', 'NN'), ('and', 'CC'), ('a', 'DT'), ('small', 'JJ'), ('disposable', 'JJ'), ('camera', 'NN'), ('on', 'IN'), ('Oleg', 'NNP'), ("'s", 'POS'), ('tray', 'NN'), ('table', 'NN'), ('.', '.')], [('The', 'DT'), ('passport', 'NN'), ('is', 'VBZ'), ('set', 'VBN'), ('down', 'RP'), ('.', '.')], [('Oleg', 'NN'), ('picks', 'NNS'), ('it', 'PRP'), ('up', 'RP'), ('.', '.')], [('We', 'PRP'), ('hear', 'VBP'), ('Emil', 'NNP'), ("'s", 'POS'), ('voice', 'NN'), ('in', 'IN'), ('CZECH', 'NNP'), ('.', '.')], [('The', 'DT'), ('scene', 'NN'), ('is', 'VBZ'), ('subtitled', 'VBN'), ('in', 'IN'), ('ENGLISH', 'NNP'), ('.', '.')], [('Just', 'RB'), ('do', 'VB'), ('what', 'WP'), ('I', 'PRP'), ('do', 'VBP'), ('.', '.')], [('Say', 'NNP'), ('the', 'DT'), ('same', 'JJ'), ('thing', 'NN'), ('I', 'PRP'), ('say', 'VBP'), ('.', '.')], [('Do', 'VBP'), ("n't", 'RB'), ('open', 'VB'), ('your', 'PRP$'), ('mouth', 'NN'), ('.', '.')], [('Okay', 'NNP'), ('.', '.')], [('CAMERA', 'NN'), ('DOLLIES', 'NNP'), ('down', 'IN'), ('a', 'DT'), ('long', 'JJ'), ('line', 'NN'), ('of', 'IN'), ('passengers', 'NNS'), ('.', '.')], [('They', 'PRP'), ('are', 'VBP'), ('split', 'VBN'), ('into', 'IN'), ('two', 'CD'), ('lines', 'NNS'), ('-', ':'), ('one', 'NN'), ('for', 'IN'), ('Americans', 'NNPS'), (',', ','), ('the', 'DT'), ('other', 'JJ'), ('for', 'IN'), ('visitors', 'NNS'), ('.', '.')], [('CAMERA', 'NNP'), ('finally', 'RB'), ('arrives', 'VBZ'), ('at', 'IN'), ('EMIL', 'NNP'), ('SLOVAK', 'NNP'), ('.', '.')], [('An', 'DT'), ('unshaven', 'JJ'), ('Czech', 'NNP'), ('in', 'IN'), ('his', 'PRP$'), ('mid-30', 'NN'), ("'s", 'POS'), ('.', '.')], [('Tall', 'NNP'), (',', ','), ('scraggly', 'RB'), ('beard', 'NN'), ('.', '.')], [('Piercing', 'VBG'), ('blue', 'JJ'), ('eyes', 'NNS'), ('.', '.')], [('He', 'PRP'), ("'s", 'VBZ'), ('dressed', 'VBN'), ('in', 'IN'), ('an', 'DT'), ('outdated', 'JJ'), ('suit', 'NN'), ('.', '.')], [('His', 'PRP$'), ('eyes', 'NNS'), ('are', 'VBP'), ('alert', 'JJ'), (',', ','), ('cunning', 'VBG'), ('and', 'CC'), ('smart', 'JJ'), ('.', '.')], [('OLEG', 'NNP'), ('RAZGUL', 'NNP'), (',', ','), ('stands', 'VBZ'), ('in', 'IN'), ('line', 'NN'), ('behind', 'IN'), ('Emil', 'NNP'), ('.', '.')], [('Oleg', 'NNP'), ('is', 'VBZ'), ('big', 'JJ'), ('.', '.')], [('Not', 'RB'), ('tall', 'JJ'), ('-', ':'), ('but', 'CC'), ('wide', 'JJ'), ('.', '.')], [('A', 'DT'), ('wr ...

# %%
words = get_lemmatized_words(sent)
print(words)
# Out:
# ['word', 'CZECH', 'AIRLINE', 'We', 'pan', 'across', 'word', 'side', 'plane', 'tray', 'table', 'Crumpled', 'Czech', 'bill', 'coin', 'Hands', 'count', 'money', 'The', 'airline', 'hostess', 'announce', 'arrival', 'JFK', 'CZECH', 'A', 'hand', 'reach', 'breast', 'pocket', 'pull', 'two', 'passport', 'One', 'open', 'Belongs', 'EMIL', 'SLOVAK', 'The', 'next', 'passport', 'belongs', 'OLEG', 'RAZGUL', 'The', 'hand', 'pass', 'Oleg', 'Razgul', 'passport', 'man', 'next', 'We', 'notice', 'several', 'empty', 'airline', 'bottle', 'vodka', 'small', 'disposable', 'camera', 'Oleg', "'s", 'tray', 'table', 'The', 'passport', 'set', 'Oleg', 'pick', 'We', 'hear', 'Emil', "'s", 'voice', 'CZECH', 'The', 'scene', 'subtitle', 'ENGLISH', 'Just', 'I', 'Say', 'thing', 'I', 'say', 'Do', "n't", 'open', 'mouth', 'Okay', 'CAMERA', 'DOLLIES', 'long', 'line', 'passenger', 'They', 'split', 'two', 'line', 'one', 'Americans', 'visitor', 'CAMERA', 'finally', 'arrive', 'EMIL', 'SLOVAK', 'An', 'unshaven', 'Czech', 'mid-30', "'s", 'Tall', 'scraggly', 'beard', 'Piercing', 'blue', 'eye', 'He', "'s", 'dress', 'outdated', 'suit', 'His', 'eye', 'alert', 'cunning', 'smart', 'OLEG', 'RAZGUL', 'stand', 'line', 'behind', 'Emil', 'Oleg', 'big', 'Not', 'tall', 'wide', 'A', 'wrestler', "'s", 'body', 'Emil', 'look', 'Oleg', 'The', 'following', 'CZECH', 'subtitle', 'ENGLISH', 'Do', "n't", 'fool', 'around', 'Okay', 'Oleg', 'hold', 'disposable', 'camera', 'arm', 'length', 'take', 'picture', 'Did', 'hear', 'I', 'say', 'I', 'want', 'document', 'trip', 'America', 'Next', 'Emil', 'step', 'Could', 'I', 'see', 'document', 'please', 'Yes', 'sir', 'He', 'hand', 'passport', 'officer', 'run', 'image', 'swipe', 'Emil', 'glance', 'furtively', 'back', 'Oleg', 'What', 'intended', 'purpose', 'visit', 'United', 'States', 'Two', 'week', 'holiday', 'How', 'much', 'money', 'carry', 'I', 'five-hundred', 'dollar', 'Can', 'show', 'Sir', 'camera', 'FIS', 'area', 'Oleg', 'take', 'picture', 'Emil', 'Immigration', 'Officer', 'Oleg', 'put', 'camera', 'away', 'Smiles', 'sheepishly', 'Emil', 'Is', 'Are', 'travel', 'together', 'Yes', 'Please', 'join', 'u', 'Oleg', 'Come', 'forward', 'Is', 'problem', 'No', "'re", 'travel', 'together', 'I', 'want', 'talk', 'together', 'Hi', 'Can', 'I', 'take', 'look', 'document', 'take', 'Oleg', "'s", 'passport', 'Are', 'relate', 'Yes', '...', "'s", 'friend', 'Okay', 'You', "'re", 'Czech', 'national', "'re", 'Russian', 'national', 'How', 'know', 'one', 'another', 'Oleg', 'start', 'speak', 'Emil', 'cut', 'We', 'Prague', 'Oleg', 'How', 'long', 'plan', 'stay', 'Two', 'week', 'I', "'d", 'like', 'speak', 'okay', 'He', "n't", 'speak', 'English', 'I', 'speak', 'English', 'Oleg', 'Then', 'answer', 'question', 'Where', 'plan', 'stay', 'two', 'week', "'re", 'New', 'York', 'Yes', "'re", 'New', 'York', 'But', 'plan', 'stay', 'New', 'York', 'A', 'cheap', 'hotel', 'What', 'come', 'I', "'m", 'movie', 'Movies', '...', 'movie', 'see', 'movie', 'Yes', 'No', 'Both', 'When', 'I', 'boy', 'I', 'see', 'movie', 'school', 'call', '``', 'It', "'s", 'Wonderful', 'Life', "''", 'direct', 'Frank', 'Capra', 'Ever', 'since', 'I', 'want', 'come', 'America', 'Land', 'free', 'Home', 'brave', 'A', 'land', 'anyone', 'anything', 'As', 'long', 'white', 'Excuse', 'He', 'make', 'joke', 'bad', 'joke', 'First', 'time', 'airplane', '...', 'The', 'SUPERVISOR', 'come', 'see', 'problem', 'Well', "'ve", 'get', 'valid', 'visa', "n't", 'much', 'money', 'Uh', '...', 'I', "'m", '...', 'uh', 'I', 'think', "'s", 'possibility', 'may', 'come', 'live', 'reside', 'Look', 'long', 'line', 'We', 'get', 'ta', 'move', "'em", 'I', "'ll", 'take', 'secondary', 'Emil', 'look', 'Oleg', 'piss', 'The', 'place', 'empty', 'except', 'one', 'table', 'end', 'bar', 'EDDIE', 'FLEMMING', 'Manhattan', "'s", 'famous', 'detective', 'savvy', 'black', 'partner', 'LEON', 'JACKSON', 'cocktail', 'Eddie', 'smoothly', 'handsome', 'tough', 'smart', 'tired', 'Not', 'best', 'homicide', 'detective', 'Manhattan', 'ever', 'see', "'s", 'continually', 'mention', 'New', 'York', ...

# %%
print(get_pos_counts(sent))
# Out:
# (594, 2404, {'': 14986, 'noun': 6707, 'verb': 4904, 'adv': 1584, 'adj': 956}, {'': 283, 'noun': 2104, 'verb': 1185, 'adv': 187, 'adj': 477})

# %%
# defining a script to do it all together

def extract_text_features(txt):
    txt = txt.replace('\n',' ').replace('\t', ' ').replace('\r', ' ')
    sent = get_tagged_sentences(txt)
    sentence_count = len(sent)
    words = get_lemmatized_words(sent)
    word_count = len(words)
    words_nunique = len(set(words))
    (prop_nunique, prop_count, pos_counts_dict, pos_nunique_dict) = get_pos_counts(sent)
    verb_percent = pos_counts_dict['verb']*100.0/word_count
    noun_percent = pos_counts_dict['noun']*100.0/word_count
    adj_percent = pos_counts_dict['adj']*100.0/word_count
    adv_percent = pos_counts_dict['adv']*100.0/word_count

    verb_unique_percent = pos_nunique_dict['verb']*100.0/words_nunique
    noun_unique_percent = pos_nunique_dict['noun']*100.0/words_nunique
    adj_unique_percent = pos_nunique_dict['adj']*100.0/words_nunique
    adv_unique_percent = pos_nunique_dict['adv']*100.0/words_nunique

    return [prop_count, verb_percent, noun_percent, adj_percent, adv_percent,
            prop_nunique, verb_unique_percent, noun_unique_percent, 
            adj_unique_percent, adv_unique_percent]

# %%
print(extract_text_features(txt))
# Out:
# [2404, 32.2165287084483, 44.06122717119958, 6.280383655235843, 10.40599132834056, 594, 38.275193798449614, 67.95865633074935, 15.406976744186046, 6.040051679586563]
